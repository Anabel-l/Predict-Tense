# %% [markdown]
# <a href="https://colab.research.google.com/github/Anabel-l/Predict-Tense/blob/main/Predict_Tense.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#This cell sets up the model.
import re
import json
import sys
import collections
import os
import torch
import torch.nn as nn
from datetime import datetime


# single-direction RNN, optionally tied embeddings
class Emb_RNNLM(nn.Module):
    def __init__(self, params, use_LSTM=True):
        super(Emb_RNNLM, self).__init__()
        self.vocab_size = params['vocab_size']
        self.d_emb = params['d_emb']
        self.n_layers = params['num_layers']
        self.d_hid = params['d_hid']
        self.embeddings = nn.Embedding(self.vocab_size, self.d_emb)
        self.use_LSTM = use_LSTM
        if use_LSTM:
            print('Using LSTM model')
            self.i2R = nn.LSTM(self.d_emb, self.d_hid, batch_first=True, num_layers=self.n_layers) #input to recurrent layer, default nonlinearity is tanh
        else:
            # input to recurrent layer, default nonlinearity is tanh
            self.i2R = nn.RNN(
                self.d_emb, self.d_hid, batch_first=True, num_layers = self.n_layers
            )
        # recurrent to output layer
        self.R2o = nn.Linear(self.d_hid, self.vocab_size)

    def forward(self, train_datum):
        embs = torch.unsqueeze(self.embeddings(train_datum), 0)
        if self.use_LSTM:
            output, (hidden, context) = self.i2R(embs)
        else:
            output, hidden = self.i2R(embs)
        return self.R2o(output) #The second and third returned values are not used for training but for probing the model to see what it is encoding.

# %%
import re
import json
import sys
import collections
import os
import random
import torch
import torch.nn as nn
import numpy as np
import random

verbose = False
sentences = collections.defaultdict(lambda: [])
sentences_test = collections.defaultdict(lambda: [])
models = {}
book_title = 'phonemized_forms'
save_path = 'drive/MyDrive/Colab Notebooks/' + book_title + '_lstm_checkpoint.pth'
words = ['<s>', '<e>']
words_test = ['<s>', '<e>']
reg_words = []
reg_test_words = []
if os.path.isfile('drive/MyDrive/Colab Notebooks/'+book_title):
    print('Processing file', book_title)
    with open('drive/MyDrive/Colab Notebooks/'+book_title, 'r') as f0:
        for ir, line in enumerate(f0.readlines()):
            sentence_buffer = ['<s>']
            if ir % 100 == 0:
                print('Processed', ir, 'lines.')
            line = line.rstrip()
            if len(line) < 1:
                continue
            #if re.search(r'^[A-Z][A-Z][A-Z]', line):
            #    continue
            if line == 'eres-orth past-orth r 175 irregulars out of 2171 forms about 14%':
                continue
            rand_gen = np.random.randint(low=0, high=10)
            lal = line.split()
            for c in lal[3]:
              sentence_buffer.append(c) #Putting characters of pres tense into a "sentence buffer"
              if rand_gen >= 8:
                  if lal[3] not in words_test:
                    words_test.append(c)
              else:
                  if lal[3] not in words:
                    words.append(c) #80% of the characters of the present tense
                    #are going into words and the rest into words test

            i = 0
            for c in lal[4]:
              if  i == 0 and rand_gen >= 8:
                words_test.append('<m>')
                sentence_buffer.append('<m>')
                #At the start of going through past tense, if this is a test word, put <m> next into
                #sentence buffer
              sentence_buffer.append(c)
              #We then append characters to sent buf. But what if this is not a test item? Then there is no <m>
              #to separated present and past
              if rand_gen >= 8:
                  if lal[4] not in words_test:
                    words_test.append(c)
                    #We continue to add characters to test "words" if not seen yet
              else:
                  if lal[4] not in words:
                    words.append(c) #Same for non test words
              i = i + 1
            if rand_gen >= 8:
              reg_test_words.append(lal[2] == 'reg')
            else:
              reg_words.append(lal[2] == 'reg')
              #This seems to be appending the Boolean True or False to the "words"


            if verbose: print(sentence_buffer)
            #seperate into testing & training data
            if rand_gen >= 8:
              sentences_test[book_title].append(sentence_buffer + ['<e>'])
              #print("Test", sentence_buffer)
            else:
              sentences[book_title].append(sentence_buffer + ['<e>'])
              #print("Train", sentence_buffer)
else:
  print("Could not open file.")

print('sbt', sentences[book_title])
print('stbt', sentences_test[book_title])
print('words test', words_test)
print('words', words)
print('reg words', reg_words)
print('reg test words', reg_test_words)
#shuffle lists
random.shuffle(sentences[book_title])
random.shuffle(sentences_test[book_title])

wd2ix = {}
total_words = len(words)
print('total words', total_words)
for i, word in enumerate(words):
    #print('i', i)
    wd2ix[word] = i
    if verbose: print(word)
with open('drive/MyDrive/Colab Notebooks/' + book_title + 'wd2ix.json', 'w') as f3:
    json.dump(wd2ix, f3)
sentences_as_indices = [torch.LongTensor([wd2ix[w] for w in sent])
    for sent in sentences[book_title]
  ]
#training_data = torch.stack(sentences_as_indices, 0)

params = {'vocab_size': total_words, 'd_emb': 128, 'num_layers': 1, 'd_hid': 128, 'lr': 0.0003, 'epochs': 3}

models[book_title] = Emb_RNNLM(params)
# Out:
# Processing file phonemized_forms
# Processed 0 lines.
# Processed 100 lines.
# Processed 200 lines.
# Processed 300 lines.
# Processed 400 lines.
# Processed 500 lines.
# Processed 600 lines.
# Processed 700 lines.
# Processed 800 lines.
# Processed 900 lines.
# Processed 1000 lines.
# Processed 1100 lines.
# Processed 1200 lines.
# Processed 1300 lines.
# Processed 1400 lines.
# Processed 1500 lines.
# Processed 1600 lines.
# Processed 1700 lines.
# Processed 1800 lines.
# Processed 1900 lines.
# Processed 2000 lines.
# Processed 2100 lines.
# sbt [['<s>', 'k', 'w', 'ɪ', 't', 'k', 'w', 'ɪ', 'ɾ', 'ᵻ', 'd', '<e>'], ['<s>', 't', 'ɹ', 'e', 'ɪ', 'd', 't', 'ɹ', 'e', 'ɪ', 'd', 'ᵻ', 'd', '<e>'], ['<s>', 'w', 'ɪ', 'ð', 's', 't', 'æ', 'n', 'd', 'w', 'ɪ', 'ð', 's', 't', 'ʊ', 'd', '<e>'], ['<s>', 'k', 'ɑ', 'm', 'p', 'a', 'ʊ', 'n', 'd', 'k', 'ɑ', 'm', 'p', 'a', 'ʊ', 'n', 'd', 'ᵻ', 'd', '<e>'], ['<s>', 'b', 'ʌ', 'd', 'ʒ', 'b', 'ʌ', 'd', 'ʒ', 'd', '<e>'], ['<s>', 's', 'e', 'ɪ', 'l', 's', 'e', 'ɪ', 'l', 'd', '<e>'], ['<s>', 'ɐ', 's', 'ɛ', 'n', 't', 'ɐ', 's', 'ɛ', 'n', 't', 'ᵻ', 'd', '<e>'], ['<s>', 'p', 'l', 'a', 'ɪ', 'p', 'l', 'a', 'ɪ', 'd', '<e>'], ['<s>', 's', 't', 'æ',
True, True, True, True, True, True, True, False, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, False, True, True, False, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, False, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, False, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, False, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, False, True, True, False, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, False, True, True, False, False, True, True, True, True, True, False, True, True, False, True, True, True, True, True, False, True, True, True, True, True, True, True, True]
# total words 21144
# Using LSTM model

# %%
print('cai', sentences_as_indices[0])
# Out:
# cai tensor([    0, 21330, 21162, 21331, 21316, 21330, 21162, 21331, 21316, 21331,
#             1])

# %%
#This cell trains with the model and can be skipped if training has already been done and there is a checkpoint.
#Now train

criterion = nn.CrossEntropyLoss(ignore_index=0)
optimiser = torch.optim.Adam(models[book_title].parameters(), lr=params['lr'])


for epoch in range(params['epochs']):
    ep_loss = 0
    random.shuffle(sentences_as_indices)
    for j, train_datum in enumerate(sentences_as_indices):
        if len(train_datum) < 4:
            continue
        #print('td', train_datum)
        preds = models[book_title](train_datum)
        #print('ps',preds.size())
        preds = preds[:, :-1, :].contiguous().view(-1, params['vocab_size'])
        #preds = preds[:, :-1, :]
        targets = torch.unsqueeze(train_datum, 0)
        targets = targets[:, 1:].contiguous().view(-1)

        #print(preds.size(), targets.size())
        loss = criterion(preds, targets)
        #print('loss', loss.detach())
        if torch.isnan(loss):
            print(train_datum)
        loss.backward()
        optimiser.step()
        optimiser.zero_grad()
        ep_loss += loss.detach()
        if j > 0 and j % 1000 == 0:
            print('processed', j, 'training examples')
    print('Saving checkpoint')
    torch.save({'net_state_dict': models[book_title].state_dict(),  'optimiser_state_dict': optimiser.state_dict()}, save_path)
    print('epoch', epoch, 'epoch loss', ep_loss / len(sentences_as_indices))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-d53322840130> in <cell line: 8>()
#      26             print(train_datum)
#      27         loss.backward()
# ---> 28         optimiser.step()
#      29         optimiser.zero_grad()
#      30         ep_loss += loss.detach()
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#     371                             )
#     372
# --> 373                 out = func(*args, **kwargs)
#     374                 self._optimizer_step_code()
#     375
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/optimizer.py in _use_grad(self, *args, **kwargs)
#      74             torch.set_grad_enabled(self.defaults['differentiable'])
#      75             torch._dynamo.graph_break()
# ---> 76             ret = func(self, *args, **kwargs)
#      77         finally:
#      78             torch._dynamo.graph_break()
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/adam.py in step(self, closure)
#     161                 state_steps)
#     162
# --> 163             adam(
#     164                 params_with_grad,
#     165                 grads,
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/adam.py in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     309         func = _single_tensor_adam
#     310
# --> 311     func(params,
#     312          grads,
#     313          exp_avgs,
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/adam.py in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     430                 denom = (max_exp_avg_sqs[i].sqrt() / bias_correction2_sqrt).add_(eps)
#     431             else:
# --> 432                 denom = (exp_avg_sq.sqrt() / bias_correction2_sqrt).add_(eps)
#     433
#     434             param.addcdiv_(exp_avg, denom, value=-step_size)
#
# KeyboardInterrupt:

# %%
import random
import numpy as np
import torch
import torch.nn as nn
import os
softmax = nn.Softmax(dim=-1)

book_title = 'phonemized_forms'
if os.path.exists(save_path):
    checkpoint = torch.load(save_path)
    print('Loading checkpoint')
    models[book_title].load_state_dict(checkpoint['net_state_dict'])
    models[book_title].eval()
else:
    print('No checkpoint found')
    exit()

choose_randomly = True

with torch.no_grad():
    accumulated_words = ['<s>']
    indices_of_accumulated_words = torch.LongTensor([wd2ix[w] for w in accumulated_words])
    next_wd = models[book_title](indices_of_accumulated_words)
    irreg_correct = 0
    irreg_total = 0
    correct = 0
    total = 0

    pred_wds = []
    real_wds = []
    current_wd = input("Enter seed word (enter <s> for random):")

    real_accumulated = ['<s>']
    for it, wd in enumerate(sentences_test[book_title]):
      state = 0
      accumulated_words = []
      real_accumulated = []
      for ch in wd:
        #jump to the test test data if it's the past tense
        if ch == '<m>':
          state = 1
        if ch == '<s>': continue
        #else add the character to the list
        if state == 0:
          accumulated_words.append(ch)
        if state == 1:
          if ch == '<m>': continue
          if ch == '<e>': continue
          real_accumulated.append(ch)

      real_wds.append(''.join(real_accumulated))
      original_wd = ''.join(accumulated_words)
      chosen_wd = ''
      pred_wd = []
      while not chosen_wd == '<e>':
        if not chosen_wd == '': pred_wd.append(chosen_wd)
        #print('ac1', accumulated_words)
        indices_of_accumulated_words = torch.LongTensor([wd2ix[w] for w in accumulated_words])
        next_wd = models[book_title](indices_of_accumulated_words)

        next_wd_as_array = next_wd[0,-1,:].numpy()
        best_index = np.argmax(next_wd_as_array)
        chosen_wd = words[best_index]
        accumulated_words.append(chosen_wd)
      pred_wd = original_wd + ''.join(pred_wd)
      pred_wds.append(pred_wd)

      corr = ''.join(real_accumulated)
      print(original_wd, ": ", pred_wd, end = ' ')

      if(corr == pred_wd):
        if not reg_test_words[it]: irreg_correct = irreg_correct + 1
        else: correct = correct + 1
        print("correctly predicted")
      else:
        print("incorrectly predicted for", corr)
      if reg_test_words[it]: total = total + 1
      else: irreg_total = irreg_total + 1

      #print(''.join(accumulated_words))
    print("Accuracy for regular: ", correct / total)
    print("Accuracy for irregular: ", irreg_correct / irreg_total)
    print('rw', real_wds)
    print('ac', accumulated_words)
# Out:
# Loading checkpoint
# ɐvɛndʒ :  ɐvɛndʒd correctly predicted
# kəlæbɚɹeɪt :  kəlæbɚɹeɪt incorrectly predicted for kəlæbɚɹeɪɾᵻd
# ɛŋkloʊz :  ɛŋkloʊzd correctly predicted
# slʌɡ :  slʌɡd correctly predicted
# stɔl :  stɔld correctly predicted
# ɐmaʊnt :  ɐmaʊntᵻd correctly predicted
# ɐɡlɑmɚɹeɪt :  ɐɡlɑmɚɹeɪt incorrectly predicted for ɐɡlɑmɚɹeɪɾᵻd
# sɪp :  sɪpt correctly predicted
# spɛɹ :  spɛɹd correctly predicted
# bɹid :  bɹid incorrectly predicted for bɹɛd
# ʃʌn :  ʃʌnd correctly predicted
# swɛl :  swɛld correctly predicted
# aɪɾəmaɪz :  aɪɾəmaɪzd correctly predicted
# ɹᵻsid :  ɹᵻsid incorrectly predicted for ɹᵻsidᵻd
# skɹæmbəl :  skɹæmbəld correctly predicted
# pleɪɡ :  pleɪɡɹᵻd incorrectly predicted for pleɪɡd
# poʊstpoʊn :  poʊstpoʊnd correctly predicted
# steɪbɪlaɪz :  steɪbɪlaɪzd correctly predicted
# duplᵻkeɪt :  duplᵻkeɪt incorrectly predicted for duplᵻkeɪɾᵻd
# ɹaɪz :  ɹaɪzd incorrectly predicted for ɹoʊz
# pɹɑmpt :  pɹɑmpt incorrectly predicted for pɹɑmptᵻd
# lɛvi :  lɛvid correctly predicted
# dɪstɔɹt :  dɪstɔɹtɹᵻd incorrectly predicted for dɪstɔɹɾᵻd
# pɹəhɪbɪt :  pɹəhɪbɪtʃt incorrectly predicted for pɹəhɪbɪɾᵻd
# neɪl :  neɪld correctly predicted
# ɛntɚ :  ɛntɚd correctly predicted
# tɛst :  tɛst incorrectly predicted for tɛstᵻd
# kaʊnsəl :  kaʊnsəld correctly predicted
# tɹɛd :  tɹɛd incorrectly predicted for tɹɑd
# pɹəmoʊt :  pɹəmoʊt incorrectly predicted for pɹəmoʊɾᵻd
# dɹɔl :  dɹɔld correctly predicted
# poʊst :  poʊst incorrectly predicted for poʊstᵻd
# spɜ :  spɜst incorrectly predicted for spɜd
# faɪl :  faɪld correctly predicted
# ɹᵻvju :  ɹᵻvjud correctly predicted
# meɪnteɪn :  meɪnteɪnd correctly predicted
# kæɾɐlɑɡ :  kæɾɐlɑɡd correctly predicted
# pɹɑfɪt :  pɹɑfɪtʃt incorrectly predicted for pɹɑfɪɾᵻd
# kinoʊt :  kinoʊt incorrectly predicted for kinoʊɾᵻd
# kɑnvɪkt :  kɑnvɪkt incorrectly predicted for kənvɪktᵻd
# ækt :  ækt incorrectly predicted for æktᵻd
# ɛksklud :  ɛksklud incorrectly predicted for ɛkskludᵻd
# kɹaɪ :  kɹaɪst incorrectly predicted for kɹaɪd
# ɛdʒ :  ɛdʒd correctly predicted
# ɐfɜm :  ɐfɜmɪst incorrectly predicted for ɐfɜmd
# ɪnvaɪt :  ɪnvaɪtʃtɹɪst incorrectly predicted for ɪnvaɪɾᵻd
# ɛntaɪɾəl :  ɛntaɪɾəld correctly predicted
# səspɛnd :  səspɛnd incorrectly predicted for səspɛndᵻd
# stɪl :  stɪld correctly predicted
# ɡleɪz :  ɡleɪzd correctly predicted
# blɔsəm :  blɔsəmd correctly predicted
# wɪp :  wɪpppɛnd incorrectly predicted for wɪpt
# pɹəvaɪd :  pɹəvaɪd incorrectly predicted for pɹəvaɪdᵻd
# ɡaʊdʒ :  ɡaʊdʒd correctly predicted
# ʌndɚlaɪn :  ʌndɚlaɪnd correctly predicted
# stæɡɚ :  stæɡɚd correctly predicted
# ɐsɛmbəl :  ɐsɛmbəld correctly predicted
# ɹɛbəl :  ɹɛbəld incorrectly predicted for ɹᵻbɛld
# lik :  likənd incorrectly predicted for likt
# ɡæðɚ :  ɡæðɚd correctly predicted
# spɹeɪ :  spɹeɪst incorrectly predicted for spɹeɪd
# foɹtɛl :  foɹtɛld incorrectly predicted for foɹtoʊld
# vɛɹi :  vɛɹid correctly predicted
# dɹɪŋk :  dɹɪŋkənstɹɪst incorrectly predicted for dɹæŋk
# mʌstɚ :  mʌstɚd correctly predicted
# ɐpɹiʃɪeɪt :  ɐpɹiʃɪeɪt incorrectly predicted for ɐpɹiʃɪeɪɾᵻd
# kaʊnt :  kaʊntᵻd correctly predicted
# plʌmp :  plʌmpɹᵻd incorrectly predicted for plʌmpt
# beɪ :  beɪst incorrectly predicted for beɪd
# wikən :  wikənd correctly predicted
# sɔ :  sɔɹɪst incorrectly predicted for sɔd
# smɛl :  smɛld correctly predicted
# ɡʌvɚn :  ɡʌvɚnd correctly predicted
# klæɾɚ :  klæɾɚd correctly predicted
# lɛktʃɚ :  lɛktʃɚd correctly predicted
# dɪɡ :  dɪɡɹᵻd incorrectly predicted for dʌɡ
# tʃɑɹdʒ :  tʃɑɹdʒd correctly predicted
# weɪd :  weɪdʒdʒdʒɪstɹɪst incorrectly predicted for weɪdᵻd
# dɪspɜs :  dɪspɜst correctly predicted
# juɾɪlaɪz :  juɾɪlaɪzd correctly predicted
# ɹᵻfɪl :  ɹᵻfɪld correctly predicted
# pətɪʃən :  pətɪʃənd correctly predicted
# wɪðɚ :  wɪðɚd correctly predicted
# kɚɹɛkt :  kɚɹɛkt incorrectly predicted for kɚɹɛktᵻd
# ɑɹbɪtɹeɪt :  ɑɹbɪtɹeɪtʃt incorrectly predicted for ɑɹbɪtɹeɪɾᵻd
# noʊɾᵻfaɪ :  noʊɾᵻfaɪd correctly predicted
# keɪɾɚ :  keɪɾɚd correctly predicted
# fɔlsᵻfaɪ :  fɔlsᵻfaɪd correctly predicted
# sloʊ :  sloʊd correctly predicted
# koʊst :  koʊst incorrectly predicted for koʊstᵻd
# dæŋɡəl :  dæŋɡəld correctly predicted
# bᵻfɔl :  bᵻfɔld incorrectly predicted for bᵻfɛl
# slɪŋ :  slɪŋkənst incorrectly predicted for slʌŋ
# nɛst :  nɛst incorrectly predicted for nɛstᵻd
# ɹæk :  ɹækst incorrectly predicted for ɹækt
# tɹænsfɜ :  tɹænsfɜd correctly predicted
# tɹæk :  tɹækt correctly predicted
# dɹɔ :  dɹɔɹd incorrectly predicted for dɹu
# mɪnɪmaɪz :  mɪnɪmaɪzd correctly predicted
# sɛt :  sɛtʃt incorrectly predicted for sɛt
# əbzɜv :  əbzɜvd correctly predicted
# pæɹəlaɪz :  pæɹəlaɪzd correctly predicted
# sɪŋ :  sɪŋkənstɪst incorrectly predicted for sæŋ
# əfɪʃɪeɪt :  əfɪʃɪeɪtʃt incorrectly predicted for əfɪʃɪeɪɾᵻd
# ɐdvæns :  ɐdvænst correctly predicted
# ɹɛndɚ :  ɹɛndɚd correctly predicted
# bæt :  bæt incorrectly predicted for beɪɾᵻd
# flæɡ :  flæɡ incorrectly predicted for flɑʒd
# stɹoʊl :  stɹoʊld correctly predicted
# siz :  sizd correctly predicted
# fɔltɚ :  fɔltɚd correctly predicted
# kʌndʒɚ :  kʌndʒɚd correctly predicted
# ɪntᵻmət :  ɪntᵻmətʃɪst incorrectly predicted for ɪntɪmeɪɾᵻd
# laʊndʒ :  laʊndʒd correctly predicted
# fɑðɚ :  fɑðɚd correctly predicted
# ɹɪækt :  ɹɪækt incorrectly predicted for ɹɪæktᵻd
# ɛkspleɪn :  ɛkspleɪnd correctly predicted
# weɪv :  weɪvɹᵻd incorrectly predicted for weɪvd
# bʌd :  bʌd incorrectly predicted for bʌdᵻd
# ækwɪɛs :  ækwɪɛst correctly predicted
# mænɪdʒ :  mænɪdʒd correctly predicted
# ɪnɪʃɪeɪt :  ɪnɪʃɪeɪtʃɪst incorrectly predicted for ɪnɪʃɪeɪɾᵻd
# laɪt :  laɪtʃt incorrectly predicted for lɪt
# ɡlɪsən :  ɡlɪsənstɹɪst incorrectly predicted for ɡlɪsənd
# kəŋɡɹætʃʊleɪt :  kəŋɡɹætʃʊleɪt incorrectly predicted for kəŋɡɹætʃʊleɪɾᵻd
# heɪl :  heɪlɹɪkstɹɪst incorrectly predicted for heɪld
# ɐkɹu :  ɐkɹust incorrectly predicted for ɐkɹud
# dᵻɹɛkt :  dᵻɹɛkt incorrectly predicted for dᵻɹɛktᵻd
# doʊneɪt :  doʊneɪt incorrectly predicted for doʊneɪɾᵻd
# kɑnstɹʌkt :  kɑnstɹʌkt incorrectly predicted for kənstɹʌktᵻd
# ɪntɚsɛkt :  ɪntɚsɛkt incorrectly predicted for ɪntɚsɛktᵻd
# snætʃ :  snætʃt correctly predicted
# ɡeɪz :  ɡeɪzd correctly predicted
# dɪspɛl :  dɪspɛld correctly predicted
# kənstɹu :  kənstɹust incorrectly predicted for kənstɹud
# sʌbsaɪd :  sʌbsaɪd incorrectly predicted for sʌbsaɪdᵻd
# kɹɔs :  kɹɔst correctly predicted
# pɹɛs :  pɹɛst correctly predicted
# flɑɡ :  flɑɡɹᵻd incorrectly predicted for flɑɡd
# kəmpoʊz :  kəmpoʊzd correctly predicted
# dᵻvoɹs :  dᵻvoɹst correctly predicted
# laɪʔn̩ :  laɪʔn̩d correctly predicted
# oʊvɚhɪɹ :  oʊvɚhɪɹd incorrectly predicted for oʊvɚhɜd
# tʃɪɹ :  tʃɪɹd correctly predicted
# dᵻklɛɹ :  dᵻklɛɹd correctly predicted
# ʃɹʌɡ :  ʃɹʌɡd correctly predicted
# mætɹɪkjʊleɪt :  mætɹɪkjʊleɪt incorrectly predicted for mætɹɪkjʊleɪɾᵻd
# pɹeɪz :  pɹeɪzd correctly predicted
# stæk :  stækt correctly predicted
# ɐsaɪn :  ɐsaɪnd correctly predicted
# sneɪk :  sneɪkt correctly predicted
# ɹeɪs :  ɹeɪst incorrectly predicted for ɹeɪsd
# sɜv :  sɜvɚd incorrectly predicted for sɜvd
# ɹᵻsiv :  ɹᵻsivd correctly predicted
# flæʃ :  flæʃt correctly predicted
# pɜdʒ :  pɜdʒd correctly predicted
# pɪlɪdʒ :  pɪlɪdʒd correctly predicted
# dᵻmɑkɹɐtaɪz :  dᵻmɑkɹɐtaɪzd correctly predicted
# sɪmɚ :  sɪmɚstɹeɪst incorrectly predicted for sɪmɚd
# skɹitʃ :  skɹitʃt correctly predicted
# pəzɛs :  pəzɛst correctly predicted
# kæɹi :  kæɹid correctly predicted
# əblaɪdʒ :  əblaɪdʒd correctly predicted
# vælju :  væljud correctly predicted
# θɹæʃ :  θɹæʃt correctly predicted
# kənfaɪd :  kənfaɪd incorrectly predicted for kənfaɪdᵻd
# əbteɪn :  əbteɪnd correctly predicted
# ɛntɹʌst :  ɛntɹʌst incorrectly predicted for ɛntɹʌstᵻd
# ᵻɹeɪs :  ᵻɹeɪst correctly predicted
# tʌɡ :  tʌɡd correctly predicted
# sʌbsɪdaɪz :  sʌbsɪdaɪzd correctly predicted
# tæks :  tækst correctly predicted
# tʃænəl :  tʃænəld correctly predicted
# tɪk :  tɪkstɹɪst incorrectly predicted for tɪkt
# lip :  lipt correctly predicted
# pɑɹteɪk :  pɑɹteɪkt incorrectly predicted for pɑɹɾʊk
# kɐpɪtʃʊleɪt :  kɐpɪtʃʊleɪt incorrectly predicted for kɐpɪtʃʊleɪɾᵻd
# daɪleɪt :  daɪleɪtʃt incorrectly predicted for daɪleɪɾᵻd
# ɹᵻfɜ :  ɹᵻfɜd correctly predicted
# wɪn :  wɪnstʃɪst incorrectly predicted for wʌn
# pɹɛdʒudɪs :  pɹɛdʒudɪst correctly predicted
# ɐsɪst :  ɐsɪst incorrectly predicted for ɐsɪstᵻd
# nᵻɡoʊʃɪeɪt :  nᵻɡoʊʃɪeɪt incorrectly predicted for nᵻɡoʊʃɪeɪɾᵻd
# taɪʔn̩ :  taɪʔn̩d correctly predicted
# stɹæɡəl :  stɹæɡəld correctly predicted
# daɪv :  daɪvɹᵻd incorrectly predicted for dʌv
# kʌpəl :  kʌpəld correctly predicted
# ɛŋkaʊntɚ :  ɛŋkaʊntɚd correctly predicted
# soʊ :  soʊnd incorrectly predicted for soʊd
# ɪmædʒɪn :  ɪmædʒɪnd correctly predicted
# weɪdʒɚ :  weɪdʒɚdʒdɪstɹeɪd incorrectly predicted for weɪdʒɚd
# noʊt :  noʊt incorrectly predicted for noʊɾᵻd
# wɪɡəl :  wɪɡəlnd incorrectly predicted for wɪɡəld
# mɛs :  mɛst correctly predicted
# pɹɪzum :  pɹɪzumd correctly predicted
# daɪəɡnoʊz :  daɪəɡnoʊzd correctly predicted
# ɹᵻmɛmbɚ :  ɹᵻmɛmbɚd correctly predicted
# ɡɪv :  ɡɪvstɹɪst incorrectly predicted for ɡeɪv
# sɚɹɛndɚ :  sɚɹɛndɚd correctly predicted
# pɹɪdɪkt :  pɹɪdɪkt incorrectly predicted for pɹɪdɪktᵻd
# dᵻfjuz :  dᵻfjuzd correctly predicted
# kɹʌmbəl :  kɹʌmbəld correctly predicted
# ɹᵻkaʊnt :  ɹᵻkaʊntᵻd correctly predicted
# lɛvəl :  lɛvəld correctly predicted
# stɹaɪd :  stɹaɪd incorrectly predicted for stɹoʊd
# sɑdɚ :  sɑdɚd correctly predicted
# flaɪ :  flaɪkstɹɪst incorrectly predicted for flu
# koʊɪnsaɪd :  koʊɪnsaɪd incorrectly predicted for koʊɪnsaɪdᵻd
# bɹeɪk :  bɹeɪkt incorrectly predicted for bɹoʊk
# snɔɹt :  snɔɹtɹᵻd incorrectly predicted for snɔɹɾᵻd
# ɛkspɹɛs :  ɛkspɹɛst correctly predicted
# ɛɡzɛmplᵻfaɪ :  ɛɡzɛmplᵻfaɪd correctly predicted
# tɹɑt :  tɹɑtʃt incorrectly predicted for tɹɑɾᵻd
# wɪni :  wɪnist incorrectly predicted for wɪnɪd
# kəmpɛɹ :  kəmpɛɹd correctly predicted
# ɛmptid :  ɛmptid correctly predicted
# kʌp :  kʌpt correctly predicted
# dʒɔɪn :  dʒɔɪnd correctly predicted
# pɪntʃ :  pɪntʃɪst incorrectly predicted for pɪntʃt
# dʒoʊk :  dʒoʊkt correctly predicted
# fitʃɚ :  fitʃɚd correctly predicted
# dɪsweɪd :  dɪsweɪd incorrectly predicted for dɪsweɪdᵻd
# ɐpɪɹ :  ɐpɪɹᵻd incorrectly predicted for ɐpɪɹd
# ɹeɪndʒ :  ɹeɪndʒd correctly predicted
# bæɾɚ :  bæɾɚd correctly predicted
# ʌndɚɹaɪt :  ʌndɚɹaɪtʃt incorrectly predicted for ʌndɚɹoʊt
# ɹeɪn :  ɹeɪnd correctly predicted
# ɹiəʃʊɹ :  ɹiəʃʊɹd correctly predicted
# ɛnʃʊɹ :  ɛnʃʊɹd correctly predicted
# pætɹənaɪz :  pætɹənaɪzd correctly predicted
# hɛd :  hɛd incorrectly predicted for hɛdᵻd
# kɹɛdɪt :  kɹɛdɪtɹᵻd incorrectly predicted for kɹɛdɪɾᵻd
# swɛɹ :  swɛɹd incorrectly predicted for swoɹ
# daɪəl :  daɪəld correctly predicted
# bᵻtɹeɪ :  bᵻtɹeɪd correctly predicted
# boʊ :  boʊd incorrectly predicted for baʊd
# sɪkən :  sɪkənstɹɪst incorrectly predicted for sɪkənd
# dᵻpɹaɪv :  dᵻpɹaɪvd correctly predicted
# ɐbaʊnd :  ɐbaʊnd incorrectly predicted for ɐbaʊndᵻd
# kɑmɛnt :  kɑmɛnt incorrectly predicted for kɑmɛntᵻd
# æbsənt :  æbsəntɹɪst incorrectly predicted for æbsɛntᵻd
# hɑɹk :  hɑɹkstɹɪst incorrectly predicted for hɑɹkt
# pɹɑdʒɛkt :  pɹɑdʒɛkt incorrectly predicted for pɹədʒɛktᵻd
# stoɹm :  stoɹmɪst incorrectly predicted for stoɹmd
# flɔnt :  flɔnt incorrectly predicted for flɔntᵻd
# hɪt :  hɪtʃɹᵻd incorrectly predicted for hɪt
# ɪnfluəns :  ɪnfluənst correctly predicted
# bᵻheɪv :  bᵻheɪvd correctly predicted
# daɪdʒɛst :  daɪdʒɛst incorrectly predicted for daɪdʒɛstᵻd
# eɪd :  eɪdʒdʒɪstɹɪst incorrectly predicted for eɪdᵻd
# pæɹədi :  pæɹədid correctly predicted
# ɪɹoʊd :  ɪɹoʊd incorrectly predicted for ɪɹoʊdᵻd
# ɹᵻlɪv :  ɹᵻlɪvd correctly predicted
# blɜt :  blɜt incorrectly predicted for blɜɾᵻd
# ɪntɚɹʌpt :  ɪntɚɹʌpt incorrectly predicted for ɪntɚɹʌptᵻd
# sɪft :  sɪft incorrectly predicted for sɪftᵻd
# pɹɪskɹaɪb :  pɹɪskɹaɪbəld incorrectly predicted for pɹɪskɹaɪbd
# oʊvɚteɪk :  oʊvɚteɪkt incorrectly predicted for oʊvɚtʊk
# θwɔɹt :  θwɔɹtʃɹᵻd incorrectly predicted for θwɔɹɾᵻd
# ɜdʒ :  ɜdʒd correctly predicted
# dɛlɪɡeɪt :  dɛlɪɡeɪtʃt incorrectly predicted for dɛlɪɡeɪɾᵻd
# dᵻsɛnd :  dᵻsɛnd incorrectly predicted for dᵻsɛndᵻd
# spʌndʒ :  spʌndʒd correctly predicted
# ɡɛt :  ɡɛt incorrectly predicted for ɡɑt
# æmbʊʃ :  æmbʊʃt correctly predicted
# tɹæmpəl :  tɹæmpəld correctly predicted
# stɪŋk :  stɪŋkənst incorrectly predicted for stæŋk
# ʃoʊ :  ʃoʊd correctly predicted
# dᵻnaɪ :  dᵻnaɪd correctly predicted
# lʌndʒ :  lʌndʒd correctly predicted
# koʊɔɹdᵻnət :  koʊɔɹdᵻnət incorrectly predicted for koʊɔɹdɪneɪɾᵻd
# dwɛl :  dwɛlɪtʃt incorrectly predicted for dwɛlt
# skɪp :  skɪpt correctly predicted
# ɹɛdʒɪstɚ :  ɹɛdʒɪstɚd correctly predicted
# dᵻnaʊns :  dᵻnaʊnst correctly predicted
# ɛskeɪp :  ɛskeɪpt correctly predicted
# kɔl :  kɔld correctly predicted
# blɛs :  blɛst correctly predicted
# min :  mind incorrectly predicted for mɛnt
# sɛləbɹeɪt :  sɛləbɹeɪt incorrectly predicted for sɛləbɹeɪɾᵻd
# pɹəpɛl :  pɹəpɛld correctly predicted
# vɛnt :  vɛntʃt incorrectly predicted for vɛntᵻd
# ɹᵻpoɹt :  ɹᵻpoɹtɹᵻd incorrectly predicted for ɹᵻpoɹɾᵻd
# ɪntɚvin :  ɪntɚvind correctly predicted
# snæɡ :  snæɡd correctly predicted
# sækɹᵻfaɪs :  sækɹᵻfaɪst correctly predicted
# ɹᵻkleɪm :  ɹᵻkleɪmd correctly predicted
# ɹɛkəmɛnd :  ɹɛkəmɛnd incorrectly predicted for ɹɛkəmɛndᵻd
# kənvɜt :  kənvɜt incorrectly predicted for kənvɜɾᵻd
# kənfɔɹm :  kənfɔɹmd correctly predicted
# mɛmɚɹaɪz :  mɛmɚɹaɪzd correctly predicted
# tɹænspoɹt :  tɹænspoɹt incorrectly predicted for tɹænspoɹɾᵻd
# dᵻnoʊt :  dᵻnoʊt incorrectly predicted for dᵻnoʊɾᵻd
# ɪnhɪbɪt :  ɪnhɪbɪtʃt incorrectly predicted for ɪnhɪbɪɾᵻd
# ɪnsɜt :  ɪnsɜt incorrectly predicted for ɪnsɜɾᵻd
# pɹɪzɜv :  pɹɪzɜvd correctly predicted
# sɜkəl :  sɜkəld correctly predicted
# ɹᵻbjuk :  ɹᵻbjukt correctly predicted
# ɐkjuz :  ɐkjuzd correctly predicted
# dɹim :  dɹimd correctly predicted
# ɔɡmɛnt :  ɔɡmɛnt incorrectly predicted for ɔɡmɛntᵻd
# spid :  spid incorrectly predicted for spɛd
# ʃʌdɚ :  ʃʌdɚd correctly predicted
# ɐlivɪeɪt :  ɐlivɪeɪtʃt incorrectly predicted for ɐlivɪeɪɾᵻd
# dɑɹn :  dɑɹnd correctly predicted
# sᵻkjʊɹ :  sᵻkjʊɹd correctly predicted
# dᵻmænd :  dᵻmænd incorrectly predicted for dᵻmændᵻd
# plʌndʒ :  plʌndʒd correctly predicted
# sæŋkʃən :  sæŋkʃənd correctly predicted
# ɹᵻmaɪnd :  ɹᵻmaɪnd incorrectly predicted for ɹᵻmaɪndᵻd
# ɹæli :  ɹælid correctly predicted
# fild :  fild incorrectly predicted for fildᵻd
# dɪskʌvɚ :  dɪskʌvɚd correctly predicted
# bɛɹ :  bɛɹd incorrectly predicted for boɹ
# ɪnveɪd :  ɪnveɪd incorrectly predicted for ɪnveɪdᵻd
# ʃeɪv :  ʃeɪvd correctly predicted
# dʒɜni :  dʒɜnid correctly predicted
# flæɾɚ :  flæɾɚd correctly predicted
# ɐstaʊnd :  ɐstaʊnd incorrectly predicted for ɐstaʊndᵻd
# mɜdʒ :  mɜdʒd correctly predicted
# stɑɹɾəl :  stɑɹɾəld correctly predicted
# stɹaɪk :  stɹaɪkt incorrectly predicted for stɹʌk
# slæʃ :  slæʃt correctly predicted
# sit :  sitʃt incorrectly predicted for siɾᵻd
# stɹɪŋ :  stɹɪŋkənst incorrectly predicted for stɹʌŋ
# kəmjut :  kəmjut incorrectly predicted for kəmjuɾᵻd
# spɛʃəlaɪz :  spɛʃəlaɪzd correctly predicted
# ɹul :  ɹuld correctly predicted
# tɹit :  tɹitʃt incorrectly predicted for tɹiɾᵻd
# tʃɪp :  tʃɪpt correctly predicted
# loʊkeɪt :  loʊkeɪt incorrectly predicted for loʊkeɪɾᵻd
# fɹeɪz :  fɹeɪzd correctly predicted
# ɛɡzɪbɪt :  ɛɡzɪbɪt incorrectly predicted for ɛɡzɪbɪɾᵻd
# ɪɹɛkt :  ɪɹɛkt incorrectly predicted for ɪɹɛktᵻd
# iz :  izd correctly predicted
# slænt :  slænt incorrectly predicted for slæntᵻd
# kʌvɚ :  kʌvɚd correctly predicted
# kənsaɪn :  kənsaɪnd correctly predicted
# ɹᵻdʒɛkt :  ɹᵻdʒɛkt incorrectly predicted for ɹᵻdʒɛktᵻd
# ɪnfjʊɹɹɪeɪt :  ɪnfjʊɹɹɪeɪt incorrectly predicted for ɪnfjʊɹɹɪeɪɾᵻd
# stɹeɪ :  stɹeɪst incorrectly predicted for stɹeɪd
# teɪpɚ :  teɪpɚd correctly predicted
# nʌdʒ :  nʌdʒd correctly predicted
# aʊtnʌmbɚ :  aʊtnʌmbɚd correctly predicted
# ɪntᵻɡɹeɪt :  ɪntᵻɡɹeɪtʃt incorrectly predicted for ɪntᵻɡɹeɪɾᵻd
# dɑɹkən :  dɑɹkənd correctly predicted
# stæmp :  stæmpt correctly predicted
# hɪnt :  hɪntʃt incorrectly predicted for hɪntᵻd
# kənfɛs :  kənfɛst correctly predicted
# moʊɾᵻveɪt :  moʊɾᵻveɪt incorrectly predicted for moʊɾᵻveɪɾᵻd
# fɚɡɪv :  fɚɡɪvd incorrectly predicted for fɚɡeɪv
# kəlæps :  kəlæpst correctly predicted
# ɡlɛɹ :  ɡlɛɹd correctly predicted
# θæŋk :  θæŋkst incorrectly predicted for θæŋkt
# ᵻlɛkt :  ᵻlɛkt incorrectly predicted for ᵻlɛktᵻd
# ɹiɪnfoɹs :  ɹiɪnfoɹst correctly predicted
# tɛl :  tɛld incorrectly predicted for toʊld
# aɪɚn :  aɪɚndᵻd incorrectly predicted for aɪɚnd
# spɛl :  spɛld correctly predicted
# sɪt :  sɪtʃt incorrectly predicted for sæt
# sut :  sut incorrectly predicted for suɾᵻd
# oʊbeɪ :  oʊbeɪd correctly predicted
# flʌd :  flʌd incorrectly predicted for flʌdᵻd
# feɪd :  feɪdʒdʒɪstɹɪst incorrectly predicted for feɪdᵻd
# ɹᵻpɛl :  ɹᵻpɛld correctly predicted
# laɪ :  laɪkstɹɪst incorrectly predicted for leɪ
# kɹeɪz :  kɹeɪzd correctly predicted
# daɪlut :  daɪlut incorrectly predicted for daɪluɾᵻd
# ɹænsæk :  ɹænsækt correctly predicted
# klæp :  klæpt correctly predicted
# dɪspleɪ :  dɪspleɪst incorrectly predicted for dɪspleɪd
# dɪsɐɡɹi :  dɪsɐɡɹist incorrectly predicted for dɪsæɡɹɪd
# pɚfɔɹm :  pɚfɔɹmd correctly predicted
# pɹɑmɪs :  pɹɑmɪst correctly predicted
# stɹɛtʃ :  stɹɛtʃt correctly predicted
# ɹᵻfjuz :  ɹᵻfjuzd correctly predicted
# tʃɔɹɾəl :  tʃɔɹɾəld correctly predicted
# pɹəkjʊɹ :  pɹəkjʊɹd correctly predicted
# dʒɜmᵻneɪt :  dʒɜmᵻneɪtʃt incorrectly predicted for dʒɜmᵻneɪɾᵻd
# dʒɪŋɡəl :  dʒɪŋɡəld correctly predicted
# ɹeɪz :  ɹeɪzd correctly predicted
# ɹɛkən :  ɹɛkənd correctly predicted
# wil :  wild correctly predicted
# dɹaɪv :  dɹaɪvd incorrectly predicted for dɹoʊv
# tɹænsmɪt :  tɹænsmɪt incorrectly predicted for tɹænsmɪɾᵻd
# ɑɹɡju :  ɑɹɡjud correctly predicted
# lɑk :  lɑkst incorrectly predicted for lɑkt
# kwaɪət :  kwaɪətʃt incorrectly predicted for kwaɪəɾᵻd
# sɛns :  sɛnst correctly predicted
# ɪkweɪt :  ɪkweɪtʃt incorrectly predicted for ɪkweɪɾᵻd
# ɐdʒɜn :  ɐdʒɜnd correctly predicted
# kaʊntɚ :  kaʊntɚd correctly predicted
# ʃild :  ʃild incorrectly predicted for ʃildᵻd
# dᵻleɪ :  dᵻleɪd correctly predicted
# lɪsən :  lɪsənstɹɪst incorrectly predicted for lɪsənd
# pul :  pulɾᵻd incorrectly predicted for puld
# ɐtɛnd :  ɐtɛnd incorrectly predicted for ɐtɛndᵻd
# bleɪz :  bleɪzd correctly predicted
# nɑd :  nɑd incorrectly predicted for nɑdᵻd
# stɪmjʊleɪt :  stɪmjʊleɪt incorrectly predicted for stɪmjʊleɪɾᵻd
# səpɹɛs :  səpɹɛst correctly predicted
# dʒoʊlt :  dʒoʊlt incorrectly predicted for dʒoʊltᵻd
# pleɪs :  pleɪst correctly predicted
# dʒɛnɚɹeɪt :  dʒɛnɚɹeɪtʃt incorrectly predicted for dʒɛnɚɹeɪɾᵻd
# sɜvɪs :  sɜvɪst correctly predicted
# ɹɛɡjʊleɪt :  ɹɛɡjʊleɪt incorrectly predicted for ɹɛɡjʊleɪɾᵻd
# bɑɹdʒ :  bɑɹdʒd correctly predicted
# saɪn :  saɪndɪst incorrectly predicted for saɪnd
# dæmpən :  dæmpənd correctly predicted
# oʊvɚlʊk :  oʊvɚlʊkəld incorrectly predicted for oʊvɚlʊkt
# hɜl :  hɜlɹspɹɪst incorrectly predicted for hɜld
# ɐdmɪt :  ɐdmɪtʃt incorrectly predicted for ɐdmɪɾᵻd
# su :  sust incorrectly predicted for sud
# ɪmænsᵻpeɪt :  ɪmænsᵻpeɪt incorrectly predicted for ɪmænsᵻpeɪɾᵻd
# pɹɛzənt :  pɹɛzəntɹɪd incorrectly predicted for pɹɪzɛntᵻd
# fɔɪl :  fɔɪlst incorrectly predicted for fɔɪld
# ɛndʊɹ :  ɛndʊɹᵻd incorrectly predicted for ɛndʊɹd
# pɹətɹud :  pɹətɹud incorrectly predicted for pɹətɹudᵻd
# ɐmɛnd :  ɐmɛnd incorrectly predicted for ɐmɛndᵻd
# mɑk :  mɑkənd incorrectly predicted for mɑkt
# nᵻɡlɛkt :  nᵻɡlɛkt incorrectly predicted for nᵻɡlɛktᵻd
# ɹᵻfɹeɪn :  ɹᵻfɹeɪnd correctly predicted
# smaɪl :  smaɪld correctly predicted
# ʃɑp :  ʃɑpt incorrectly predicted for ʃoʊpt
# ɛnhæns :  ɛnhænst correctly predicted
# ɹɛkɚd :  ɹɛkɚd incorrectly predicted for ɹᵻkoɹdᵻd
# ɪntɚvju :  ɪntɚvjud correctly predicted
# kaʊntɚɹækt :  kaʊntɚɹækt incorrectly predicted for kaʊntɚɹæktᵻd
# ɐbændən :  ɐbændənd correctly predicted
# ɐplaɪ :  ɐplaɪnd incorrectly predicted for ɐplaɪd
# bɑɾəl :  bɑɾəld correctly predicted
# ɡlæns :  ɡlænst correctly predicted
# ɪnsʌlt :  ɪnsʌltʃt incorrectly predicted for ɪnsʌltᵻd
# dɹim :  dɹimd incorrectly predicted for dɹɛmpt
# bit :  bitʃt incorrectly predicted for bit
# ɪmpoɹt :  ɪmpoɹtɹᵻd incorrectly predicted for ɪmpoɹɾᵻd
# ɹikənstɹʌkt :  ɹikənstɹʌkt incorrectly predicted for ɹikənstɹʌktᵻd
# maʊnt :  maʊntᵻd correctly predicted
# ɐdvaɪz :  ɐdvaɪzd correctly predicted
# Accuracy for regular:  0.5175
# Accuracy for irregular:  0.5384615384615384
�ntɚsɛktᵻd', 'snætʃt', 'ɡeɪzd', 'dɪspɛld', 'kənstɹud', 'sʌbsaɪdᵻd', 'kɹɔst', 'pɹɛst', 'flɑɡd', 'kəmpoʊzd', 'dᵻvoɹst', 'laɪʔn̩d', 'oʊvɚhɜd', 'tʃɪɹd', 'dᵻklɛɹd', 'ʃɹʌɡd', 'mætɹɪkjʊleɪɾᵻd', 'pɹeɪzd', 'stækt', 'ɐsaɪnd', 'sneɪkt', 'ɹeɪsd', 'sɜvd', 'ɹᵻsivd', 'flæʃt', 'pɜdʒd', 'pɪlɪdʒd', 'dᵻmɑkɹɐtaɪzd', 'sɪmɚd', 'skɹitʃt', 'pəzɛst', 'kæɹid', 'əblaɪdʒd', 'væljud', 'θɹæʃt', 'kənfaɪdᵻd', 'əbteɪnd', 'ɛntɹʌstᵻd', 'ᵻɹeɪst', 'tʌɡd', 'sʌbsɪdaɪzd', 'tækst', 'tʃænəld', 'tɪkt', 'lipt', 'pɑɹɾʊk', 'kɐpɪtʃʊleɪɾᵻd', 'daɪleɪɾᵻd', 'ɹᵻfɜd', 'wʌn', 'pɹɛdʒudɪst', 'ɐsɪstᵻd', 'nᵻɡoʊʃɪeɪɾᵻd', 'taɪʔn̩d', 'stɹæɡəld', 'dʌv', 'kʌpəld', 'ɛŋkaʊntɚd', 'soʊd', 'ɪmædʒɪnd', 'weɪdʒɚd', 'noʊɾᵻd', 'wɪɡəld', 'mɛst', 'pɹɪzumd', 'daɪəɡnoʊzd', 'ɹᵻmɛmbɚd', 'ɡeɪv', 'sɚɹɛndɚd', 'pɹɪdɪktᵻd', 'dᵻfjuzd', 'kɹʌmbəld', 'ɹᵻkaʊntᵻd', 'lɛvəld', 'stɹoʊd', 'sɑdɚd', 'flu', 'koʊɪnsaɪdᵻd', 'bɹoʊk', 'snɔɹɾᵻd', 'ɛkspɹɛst', 'ɛɡzɛmplᵻfaɪd', 'tɹɑɾᵻd', 'wɪnɪd', 'kəmpɛɹd', 'ɛmptid', 'kʌpt', 'dʒɔɪnd', 'pɪntʃt', 'dʒoʊkt', 'fitʃɚd', 'dɪsweɪdᵻd', 'ɐpɪɹd', 'ɹeɪndʒd', 'bæɾɚd', 'ʌndɚɹoʊt', 'ɹeɪnd', 'ɹiəʃʊɹd', 'ɛnʃʊɹd', 'pætɹənaɪzd', 'hɛdᵻd', 'kɹɛdɪɾᵻd', 'swoɹ', 'daɪəld', 'bᵻtɹeɪd', 'baʊd', 'sɪkənd', 'dᵻpɹaɪvd', 'ɐbaʊndᵻd', 'kɑmɛntᵻd', 'æbsɛntᵻd', 'hɑɹkt', 'pɹədʒɛktᵻd', 'stoɹmd', 'flɔntᵻd', 'hɪt', 'ɪnfluənst', 'bᵻheɪvd', 'daɪdʒɛstᵻd', 'eɪdᵻd', 'pæɹədid', 'ɪɹoʊdᵻd', 'ɹᵻlɪvd', 'blɜɾᵻd', 'ɪntɚɹʌptᵻd', 'sɪftᵻd', 'pɹɪskɹaɪbd', 'oʊvɚtʊk', 'θwɔɹɾᵻd', 'ɜdʒd', 'dɛlɪɡeɪɾᵻd', 'dᵻsɛndᵻd', 'spʌndʒd', 'ɡɑt', 'æmbʊʃt', 'tɹæmpəld', 'stæŋk', 'ʃoʊd', 'dᵻnaɪd', 'lʌndʒd', 'koʊɔɹdɪneɪɾᵻd', 'dwɛlt', 'skɪpt', 'ɹɛdʒɪstɚd', 'dᵻnaʊnst', 'ɛskeɪpt', 'kɔld', 'blɛst', 'mɛnt', 'sɛləbɹeɪɾᵻd', 'pɹəpɛld', 'vɛntᵻd', 'ɹᵻpoɹɾᵻd', 'ɪntɚvind', 'snæɡd', 'sækɹᵻfaɪst', 'ɹᵻkleɪmd', 'ɹɛkəmɛndᵻd', 'kənvɜɾᵻd', 'kənfɔɹmd', 'mɛmɚɹaɪzd', 'tɹænspoɹɾᵻd', 'dᵻnoʊɾᵻd', 'ɪnhɪbɪɾᵻd', 'ɪnsɜɾᵻd', 'pɹɪzɜvd', 'sɜkəld', 'ɹᵻbjukt', 'ɐkjuzd', 'dɹimd', 'ɔɡmɛntᵻd', 'spɛd', 'ʃʌdɚd', 'ɐlivɪeɪɾᵻd', 'dɑɹnd', 'sᵻkjʊɹd', 'dᵻmændᵻd', 'plʌndʒd', 'sæŋkʃənd', 'ɹᵻmaɪndᵻd', 'ɹælid', 'fildᵻd', 'dɪskʌvɚd', 'boɹ', 'ɪnveɪdᵻd', 'ʃeɪvd', 'dʒɜnid', 'flæɾɚd', 'ɐstaʊndᵻd', 'mɜdʒd', 'stɑɹɾəld', 'stɹʌk', 'slæʃt', 'siɾᵻd', 'stɹʌŋ', 'kəmjuɾᵻd', 'spɛʃəlaɪzd', 'ɹuld', 'tɹiɾᵻd', 'tʃɪpt', 'loʊkeɪɾᵻd', 'fɹeɪzd', 'ɛɡzɪbɪɾᵻd', 'ɪɹɛktᵻd', 'izd', 'slæntᵻd', 'kʌvɚd', 'kənsaɪnd', 'ɹᵻdʒɛktᵻd', 'ɪnfjʊɹɹɪeɪɾᵻd', 'stɹeɪd', 'teɪpɚd', 'nʌdʒd', 'aʊtnʌmbɚd', 'ɪntᵻɡɹeɪɾᵻd', 'dɑɹkənd', 'stæmpt', 'hɪntᵻd', 'kənfɛst', 'moʊɾᵻveɪɾᵻd', 'fɚɡeɪv', 'kəlæpst', 'ɡlɛɹd', 'θæŋkt', 'ᵻlɛktᵻd', 'ɹiɪnfoɹst', 'toʊld', 'aɪɚnd', 'spɛld', 'sæt', 'suɾᵻd', 'oʊbeɪd', 'flʌdᵻd', 'feɪdᵻd', 'ɹᵻpɛld', 'leɪ', 'kɹeɪzd', 'daɪluɾᵻd', 'ɹænsækt', 'klæpt', 'dɪspleɪd', 'dɪsæɡ ...
# ac ['ɐ', 'd', 'v', 'a', 'ɪ', 'z', 'd', '<e>']

# %% [markdown]
# The irregular accuracy tends lower than the regular accuracy which makes sense in this case, given the irregularity of the forms. However, in this particular run, the accuracy was pretty close for both.
